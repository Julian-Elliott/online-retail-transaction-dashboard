# %% [markdown]
# # **Cleaned Retail Dataset with Histograms**

# %% [markdown]
# ## Objectives
#
# * Load the cleaned Online Retail Transaction dataset and perform exploratory data visualisation by generating histograms for all numeric columns.
#
# * Identify the distribution patterns and outliers in key metrics such as Quantity, UnitPrice, and TotalPrice to guide future analysis and dashboard design.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# %%
# Load the cleaned dataset
df = pd.read_csv('../data/Cleaned_Online_Retail.csv')

# Show top 5 rows to verify the load
df.head()
# Out:
# C:\Users\petal\AppData\Local\Temp\ipykernel_30568\3714809033.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/Cleaned_Online_Retail.csv')
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...

# %%
# Show data types and nulls
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 524931 entries, 0 to 524930
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    524931 non-null  object
#  1   StockCode    524931 non-null  object
#  2   Description  524931 non-null  object
#  3   Quantity     524931 non-null  int64
#  4   InvoiceDate  524931 non-null  object
#  5   UnitPrice    524931 non-null  float64
#  6   CustomerID   524931 non-null  int64
#  7   Country      524931 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 32.0+ MB

# %% [markdown]
# ## Outputs
#
# * Visual outputs: Multi-panel histogram plots of numeric columns

# %%
# Select only numeric columns
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Plot histograms for all numeric columns in a multi-plot layout
plt.figure(figsize=(15, 10))
for i, col in enumerate(numeric_cols):
    plt.subplot(2, 3, i + 1)
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.tight_layout()

plt.suptitle("📊 Histograms of Numeric Columns", fontsize=16, y=1.05)
plt.show()
# Out:
# c:\Users\petal\Downloads\CI-DBC\vscode-projects\online-retail-transaction-dashboard\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Additional Comments
#
# * Data cleaning (removing nulls, handling cancellations, and computing TotalPrice) has already been completed in a prior ETL step.
#
# * Histogram plots help confirm data integrity and guide decisions about scaling, segmentation, or transformations required for business analysis in Power BI/Tableau.
#
# * Future visualisation steps (e.g., boxplots or log transforms) can be built on this foundational inspection.

# %% [markdown]
# ---
